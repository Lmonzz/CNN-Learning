# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
batch_size = 32
img_height = 224
img_width = 224
epochs = 16
image_shape = (img_height, img_width, 3)
train_path = r"D:\DA\dataset\aug_waste_dataset_balance\taphuanluyen"
test_path = r"D:\DA\dataset\aug_waste_dataset_balance\tapkiemthu"

# %%
train_datagen = ImageDataGenerator(rescale=1./255,validation_split = 0.2)

# %%
train_data = train_datagen.flow_from_directory(
        train_path,
        target_size=image_shape[:2],
        batch_size=batch_size,
        color_mode='rgb',
        class_mode='categorical',
        subset='training',
        shuffle=True)

val_data = train_datagen.flow_from_directory(
        train_path,
        target_size=image_shape[:2],
        color_mode='rgb',
        batch_size=batch_size,
        class_mode='categorical',
        subset='validation',
        shuffle=False)
# Out:
# Found 17959 images belonging to 14 classes.
# Found 4483 images belonging to 14 classes.

# %%
pretrained_model= InceptionV3(include_top=False,
                   input_shape=(224,224,3),
                   pooling='avg',classes=14,
                   weights='imagenet')

# %%
for layer in pretrained_model.layers:
        layer.trainable=False

# %%
#pretrained_model.summary()

# %%
last_layer = pretrained_model.get_layer('mixed7')
last_output = last_layer.output
x = layers.Flatten()(last_output)
x = layers.Dense(1024,activation="relu")(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(14 , activation="softmax")(x)
model = Model(pretrained_model.input , x)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000002),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
#model.summary()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
history = model.fit(train_data, epochs=epochs, validation_data=val_data, callbacks=[early_stop])
# Out:
# Epoch 1/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1291s 2s/step - accuracy: 0.3682 - loss: 2.0699 - val_accuracy: 0.7122 - val_loss: 1.0600
# Epoch 2/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1021s 2s/step - accuracy: 0.7574 - loss: 0.8934 - val_accuracy: 0.7892 - val_loss: 0.7589
# Epoch 3/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1103s 2s/step - accuracy: 0.8510 - loss: 0.5858 - val_accuracy: 0.8211 - val_loss: 0.6254
# Epoch 4/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1033s 2s/step - accuracy: 0.9042 - loss: 0.4191 - val_accuracy: 0.8439 - val_loss: 0.5422
# Epoch 5/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1049s 2s/step - accuracy: 0.9411 - loss: 0.3190 - val_accuracy: 0.8566 - val_loss: 0.4902
# Epoch 6/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1126s 2s/step - accuracy: 0.9630 - loss: 0.2442 - val_accuracy: 0.8731 - val_loss: 0.4428
# Epoch 7/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1107s 2s/step - accuracy: 0.9803 - loss: 0.1837 - val_accuracy: 0.8809 - val_loss: 0.4070
# Epoch 8/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1092s 2s/step - accuracy: 0.9879 - loss: 0.1404 - val_accuracy: 0.8916 - val_loss: 0.3778
# Epoch 9/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1097s 2s/step - accuracy: 0.9933 - loss: 0.1119 - val_accuracy: 0.8985 - val_loss: 0.3558
# Epoch 10/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1099s 2s/step - accuracy: 0.9957 - loss: 0.0876 - val_accuracy: 0.8992 - val_loss: 0.3391
# Epoch 11/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1083s 2s/step - accuracy: 0.9987 - loss: 0.0691 - val_accuracy: 0.9023 - val_loss: 0.3232
# Epoch 12/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1090s 2s/step - accuracy: 0.9993 - loss: 0.0555 - val_accuracy: 0.9036 - val_loss: 0.3095
# Epoch 13/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1087s 2s/step - accuracy: 0.9999 - loss: 0.0443 - val_accuracy: 0.9081 - val_loss: 0.2982
# Epoch 14/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1091s 2s/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 0.9079 - val_loss: 0.2896
# Epoch 15/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 1095s 2s/step - accuracy: 1.0000 - loss: 0.0280 - val_accuracy: 0.9110 - val_loss: 0.2806
# Epoch 16/16
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 970s 2s/step - accuracy: 0.9999 - loss: 0.0240 - val_accuracy: 0.9114 - val_loss: 0.2766

# %%
model.save('trash_classification_inceptionv3.keras')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %%
losses[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %%
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
test_data = train_datagen.flow_from_directory(
        test_path,
        target_size=image_shape[:2],
        color_mode='rgb',
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 6006 images belonging to 14 classes.

# %%
model.evaluate(test_data)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 103s 539ms/step - accuracy: 0.7805 - loss: 0.7086
# [0.6461279392242432, 0.8033633232116699]

# %%
pred_probabilities = model.predict(test_data)
predictions = np.argmax(pred_probabilities, axis=1)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 88s 460ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_data.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71       484
#            1       0.74      0.71      0.72       494
#            2       0.82      0.89      0.85       488
#            3       0.75      0.88      0.81       484
#            4       0.91      0.93      0.92       486
#            5       0.79      0.68      0.73       488
#            6       0.94      0.92      0.93       393
#            7       0.72      0.77      0.75       206
#            8       0.90      0.84      0.87       321
#            9       0.70      0.66      0.68       489
#           10       0.90      0.92      0.91       209
#           11       0.86      0.87      0.87       484
#           12       0.79      0.83      0.81       492
#           13       0.75      0.73      0.74       488
#
#     accuracy                           0.80      6006
#    macro avg       0.81      0.81      0.81      6006
# weighted avg       0.80      0.80      0.80      6006

# %%
print(confusion_matrix(test_data.classes,predictions))
# Out:
# [[333   7  10  16   1  15   2   1   4   9   6  25   1  54]
#  [  9 350  10  34   1   6   2  16   3  34   0  12   0  17]
#  [ 12   3 433   1   0  10   0   0   0   7   0   4   9   9]
#  [  5  10   0 428   7   0   0   1   4  22   0   3   1   3]
#  [  5   9   0  10 454   3   0   0   0   0   0   0   0   5]
#  [  9  14  20   7   8 331   6   1   0   7   7   1  66  11]
#  [  0   1   0  11   5   3 361   0   7   3   0   0   0   2]
#  [  5  10   4   6   0   0   0 158   1  18   0   1   3   0]
#  [  2   4   1   4   5   0   0   4 271   8   0   0  15   7]
#  [  6  42  20  28   1  10   5  35   7 325   2   3   4   1]
#  [  2   3   0   5   0   0   0   0   1   2 193   3   0   0]
#  [ 11   6  20   0   0   1   5   0   3   3   2 420   4   9]
#  [ 18   1   7   4   0  24   0   2   0  19   3   3 410   1]
#  [ 38  16   0  17  15  15   2   0   1   7   1  12   6 358]]

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(confusion_matrix(test_data.classes, predictions), annot=True)
# Out:
# <Axes: >
